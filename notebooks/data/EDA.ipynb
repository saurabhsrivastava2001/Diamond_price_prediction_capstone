# %%
# INJUST THE DATA

# %%
import pandas as pd

# %%
data=pd.read_csv('train2.csv')

# %%
data.head()
# Out:
#    Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 0                      0.23        Ideal     E     SI2   61.5   55.0
# 1                      0.21      Premium     E     SI1   59.8   61.0
# 2                      0.23         Good     E     VS1   56.9   65.0
# 3                      0.29      Premium     I     VS2   62.4   58.0
# 4                      0.31         Good     J     SI2   63.3   58.0
#
#    Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 0                   326       3.95      3.98      2.43
# 1                   326       3.89      3.84      2.31
# 2                   327       4.05      4.07      2.31
# 3                   334       4.20      4.23      2.63
# 4                   335       4.34      4.35      2.75

# %%
data.tail()
# Out:
#        Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 53935                      0.72        Ideal     D     SI1   60.8   57.0
# 53936                      0.72         Good     D     SI1   63.1   55.0
# 53937                      0.70    Very Good     D     SI1   62.8   60.0
# 53938                      0.86      Premium     H     SI2   61.0   58.0
# 53939                      0.75        Ideal     D     SI2   62.2   55.0
#
#        Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 53935                  2757       5.75      5.76      3.50
# 53936                  2757       5.69      5.75      3.61
# 53937                  2757       5.66      5.68      3.56
# 53938                  2757       6.15      6.12      3.74
# 53939                  2757       5.83      5.87      3.64

# %%
data.sample(5)
# Out:
#        Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 42917                      0.53         Good     F     SI1   63.8   58.0
# 40282                      0.30        Ideal     I    VVS2   62.5   54.0
# 35555                      0.35      Premium     G     VS1   60.7   61.0
# 41226                      0.43        Ideal     D     VS1   62.1   56.0
# 47002                      0.53        Ideal     G    VVS2   62.6   56.0
#
#        Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 42917                  1363       5.17      5.12      3.28
# 40282                   495       4.27      4.31      2.68
# 35555                   906       4.58      4.54      2.77
# 41226                  1207       4.85      4.87      3.02
# 47002                  1818       5.16      5.19      3.24

# %%
data.isnull().sum()
# Out:
# Carat(Weight of Daimond)    0
# Cut(Quality)                0
# Color                       0
# Clarity                     0
# Depth                       0
# Table                       0
# Price(in US dollars)        0
# X(length)                   0
# Y(width)                    0
# Z(Depth)                    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Carat(Weight of Daimond)  53940 non-null  float64
#  1   Cut(Quality)              53940 non-null  object
#  2   Color                     53940 non-null  object
#  3   Clarity                   53940 non-null  object
#  4   Depth                     53940 non-null  float64
#  5   Table                     53940 non-null  float64
#  6   Price(in US dollars)      53940 non-null  int64
#  7   X(length)                 53940 non-null  float64
#  8   Y(width)                  53940 non-null  float64
#  9   Z(Depth)                  53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
data.duplicated().sum()
# Out:
# np.int64(146)

# %%
data.shape
# Out:
# (53940, 10)

# %%
# CAT VS NUM

cat_col=data.columns[data.dtypes=="object"]

# %%
num_col=data.columns[data.dtypes!="object"]

# %%
data[cat_col]
# Out:
#       Cut(Quality) Color Clarity
# 0            Ideal     E     SI2
# 1          Premium     E     SI1
# 2             Good     E     VS1
# 3          Premium     I     VS2
# 4             Good     J     SI2
# ...            ...   ...     ...
# 53935        Ideal     D     SI1
# 53936         Good     D     SI1
# 53937    Very Good     D     SI1
# 53938      Premium     H     SI2
# 53939        Ideal     D     SI2
#
# [53940 rows x 3 columns]

# %%
data[num_col]
# Out:
#        Carat(Weight of Daimond)  Depth  Table  Price(in US dollars)  \
# 0                          0.23   61.5   55.0                   326
# 1                          0.21   59.8   61.0                   326
# 2                          0.23   56.9   65.0                   327
# 3                          0.29   62.4   58.0                   334
# 4                          0.31   63.3   58.0                   335
# ...                         ...    ...    ...                   ...
# 53935                      0.72   60.8   57.0                  2757
# 53936                      0.72   63.1   55.0                  2757
# 53937                      0.70   62.8   60.0                  2757
# 53938                      0.86   61.0   58.0                  2757
# 53939                      0.75   62.2   55.0                  2757
#
#        X(length)  Y(width)  Z(Depth)
# 0           3.95      3.98      2.43
# 1           3.89      3.84      2.31
# ...

# %%
data[num_col].describe()
# Out:
#        Carat(Weight of Daimond)         Depth         Table  \
# count              53940.000000  53940.000000  53940.000000
# mean                   0.797940     61.749405     57.457184
# std                    0.474011      1.432621      2.234491
# min                    0.200000     43.000000     43.000000
# 25%                    0.400000     61.000000     56.000000
# 50%                    0.700000     61.800000     57.000000
# 75%                    1.040000     62.500000     59.000000
# max                    5.010000     79.000000     95.000000
#
#        Price(in US dollars)     X(length)      Y(width)      Z(Depth)
# count          53940.000000  53940.000000  53940.000000  53940.000000
# mean            3932.799722      5.731157      5.734526      3.538734
# std             3989.439738      1.121761      1.142135      0.705699
# min              326.000000      0.000000      0.000000      0.000000
# 25%              950.000000      4.710000      4.720000      2.910000
# ...

# %%
data[cat_col]["Cut(Quality)"].value_counts()
# Out:
# Cut(Quality)
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
data[cat_col]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
data[cat_col]["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
# for numeric data we can plot the histogram
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (4,2))

for col in num_col:
    sns.histplot(data=data, x=col, kde=True)
    plt.show()

# %%
# plot categorical columns either bar chart or count

# %%
sns.heatmap(data[num_col].corr(),annot=True)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['Carat(Weight of Daimond)', 'Cut(Quality)', 'Color', 'Clarity', 'Depth',
#        'Table', 'Price(in US dollars)', 'X(length)', 'Y(width)', 'Z(Depth)'],
#       dtype='object')

# %%
data["Cut(Quality)"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# ## encoding categorical columns --

# %%
data["Carat(Weight of Daimond)"].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
data["clarity"].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
data["color"].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
#ORDINAL ENCODING

cut_map= {"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

clarity_map= {"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

color_map= {"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
data["cut"]=data["cut"].map(cut_map)

# %%
data["clarity"]=data["clarity"].map(clarity_map)

# %%
data["color"]=data["color"].map(color_map)

# %%
data.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
