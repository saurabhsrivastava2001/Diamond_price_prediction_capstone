# %%
import logging
import os
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 11, 22, 7, 25, 59, 115120)

# %%
f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
# Out:
# '11_22_2023_07_25_59.log'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\SAURABH SRIVASTAVA\\Desktop\\firstENDTOEND\\notebooks'

# %%
import logger

# %%
pip list
# Out:
# Package             Version
# ------------------- ------------
# asttokens           2.4.1
# backcall            0.2.0
# colorama            0.4.6
# comm                0.2.0
# contourpy           1.1.1
# cycler              0.12.1
# dataclasses         0.6
# debugpy             1.8.0
# decorator           5.1.1
# executing           2.0.1
# fonttools           4.44.3
# importlib-metadata  6.8.0
# importlib-resources 6.1.1
# ipykernel           6.26.0
# ipython             8.12.3
# jedi                0.19.1
# joblib              1.3.2
# jupyter_client      8.6.0
# jupyter_core        5.5.0
# kiwisolver          1.4.5
# matplotlib          3.7.3
# matplotlib-inline   0.1.6
# nest-asyncio        1.5.8
# numpy               1.24.4
# packaging           23.2
# pandas              2.0.3
# parso               0.8.3
# pathlib             1.0.1
# pickleshare         0.7.5
# Pillow              10.1.0
# pip                 23.3
# platformdirs        4.0.0
# prompt-toolkit      3.0.41
# psutil              5.9.6
# pure-eval           0.2.2
# Pygments            2.16.1
# pyparsing           3.1.1
# python-dateutil     2.8.2
# pytz                2023.3.post1
# pywin32             306
# pyzmq               25.1.1
# scikit-learn        1.3.2
# scipy               1.10.1
# seaborn             0.13.0
# setuptools          68.0.0
# six                 1.16.0
# stack-data          0.6.3
# threadpoolctl       3.2.0
# tornado             6.3.3
# traitlets           5.13.0
# typing_extensions   4.8.0
# tzdata              2023.3
# wcwidth             0.2.10
# wheel               0.41.2
# zipp                3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
logger.logging.info("current 3")

# %%
import sys


class Customexception(Exception):
    def __init__(self, error_message ,error_details:sys):
        self.error_message = error_message
        _,_,exe_tb = error_details.exc_info()
        
        self.lineno= exe_tb.tb_lineno
        self.file_name= exe_tb.tb_frame.f_code.co_filename   
        
    def __str__(self):
        return "Error occured in python scrit name [{0}] line number [{1}] error massage [{2}]".format(
            self.file_name, self.lineno, self.error_message)

# %%
import sys
sys.path.append("C:\\Users\\SAURABH SRIVASTAVA\\Desktop\\firstENDTOEND\\src\\DimondPricePrediction\\pipelines")
from prediction_pipeline import CustomData

# %%
import sys

# %%
try:
    1/0
except Exception as e:
    _,_,exe_tb =sys.exc_info()
    print("absolute path:",exe_tb.tb_frame.f_code.co_filename)
    print("line no:",exe_tb.tb_lineno)
    print("Error name:",e)
# Out:
# absolute path: C:\Users\SAURABH SRIVASTAVA\AppData\Local\Temp\ipykernel_10716\2671057501.py
# line no: 2
# Error name: division by zero

# %%
class customexception(Exception):
    def __init__(self):
        pass
    def __str__(self):
        pass

# %%
sys.exc_info()
# Out:
# (None, None, None)

# %%
from src.DiamondPricePrediction.utils.utils import save_object
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\SAURABH SRIVASTAVA\Desktop\firstENDTOEND\notebooks\research.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SAURABH%20SRIVASTAVA/Desktop/firstENDTOEND/notebooks/research.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> from src.DiamondPricePrediction.utils.utils import save_object
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
sys.path.append("C:\\Users\\SAURABH SRIVASTAVA\\Desktop\\firstENDTOEND\\src\\DimondPricePrediction\\utils")

# %%
sys.path.append("C:\\Users\\SAURABH SRIVASTAVA\\Desktop\\firstENDTOEND\\src\\DimondPricePrediction\\utils")

from utils import save_object

# %%
import pandas as pd

# %%
data=pd.read_csv(r"D:\Desktop\DiamondPricePrediction-main\notebooks\data\train2.csv")

# %%
data
# Out:
#        Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 0                          0.23        Ideal     E     SI2   61.5   55.0
# 1                          0.21      Premium     E     SI1   59.8   61.0
# 2                          0.23         Good     E     VS1   56.9   65.0
# 3                          0.29      Premium     I     VS2   62.4   58.0
# 4                          0.31         Good     J     SI2   63.3   58.0
# ...                         ...          ...   ...     ...    ...    ...
# 53935                      0.72        Ideal     D     SI1   60.8   57.0
# 53936                      0.72         Good     D     SI1   63.1   55.0
# 53937                      0.70    Very Good     D     SI1   62.8   60.0
# 53938                      0.86      Premium     H     SI2   61.0   58.0
# 53939                      0.75        Ideal     D     SI2   62.2   55.0
#
#        Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# 0                       326       3.95      3.98      2.43
# 1                       326       3.89      3.84      2.31
# 2                       327       4.05      4.07      2.31
# 3                       334       4.20      4.23      2.63
# 4                       335       4.34      4.35      2.75
# ...                     ...        ...       ...       ...
# 53935                  2757       5.75      5.76      3.50
# 53936                  2757       5.69      5.75      3.61
# 53937                  2757       5.66      5.68      3.56
# 53938                  2757       6.15      6.12      3.74
# 53939                  2757       5.83      5.87      3.64
#
# [53940 rows x 10 columns]
